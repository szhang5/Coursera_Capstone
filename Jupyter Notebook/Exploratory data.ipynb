# %% [markdown]
# ## Project Description
# Find factors that related to 'accident severity'

# %% [markdown]
# ### 1. Importing the required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualization
import matplotlib.pyplot as plt #visualization
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# ### 2. Loading the data in to the data frame

# %%
df = pd.read_csv("Data-Collisions.csv")
df.head(10)
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
# 5             1 -122.387598  47.690575         6  320840     322340  E919477
# 6             1 -122.338485  47.618534         7   83300      83300  3282542
# 7             2 -122.320780  47.614076         9  330897     332397  EA30304
# 8             1 -122.335930  47.611904        10   63400      63400  2071243
# 9             2 -122.384700  47.528475        12   58600      58600  2072105
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# ...

# %% [markdown]
# ### 3. Checking the types of data

# %%
df.dtypes
# Out:
# SEVERITYCODE        int64
# X                 float64
# Y                 float64
# OBJECTID            int64
# INCKEY              int64
# COLDETKEY           int64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC      object
# SEVERITYCODE.1      int64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# ...

# %% [markdown]
# ### 4. Dropping irrelevant columns

# %%
# df = df.drop(['SEVERITYCODE', 'X', 'Y', 'INCKEY', 'COLDETKEY', 'INTKEY', 'REPORTNO', 'EXCEPTRSNCODE', 'EXCEPTRSNDESC', 'SDOT_COLCODE', 'SDOT_COLDESC', 'SDOTCOLNUM', 'ST_COLCODE', 'ST_COLDESC'], axis=1)
# df = df.drop(['OBJECTID', 'STATUS', 'LOCATION', 'PERSONCOUNT', 'PEDCYLCOUNT', 'PEDCOUNT', 'VEHCOUNT', 'JUNCTIONTYPE'], axis=1)
# df = df.drop(['ADDRTYPE', 'INCDATE', 'INCDTTM', 'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR'], axis=1)
df.head(10)
# Out:
#    SEVERITYCODE.1                    SEVERITYDESC COLLISIONTYPE  \
# 0               2                Injury Collision        Angles
# 1               1  Property Damage Only Collision     Sideswipe
# 2               1  Property Damage Only Collision    Parked Car
# 3               1  Property Damage Only Collision         Other
# 4               2                Injury Collision        Angles
# 5               1  Property Damage Only Collision        Angles
# 6               1  Property Damage Only Collision        Angles
# 7               2                Injury Collision        Cycles
# 8               1  Property Damage Only Collision    Parked Car
# 9               2                Injury Collision        Angles
#
#   INATTENTIONIND UNDERINFL   WEATHER ROADCOND                LIGHTCOND  \
# 0            NaN         N  Overcast      Wet                 Daylight
# 1            NaN         0   Raining      Wet  Dark - Street Lights On
# ...

# %%
df.count()
# Out:
# OBJECTID          194673
# STATUS            194673
# ADDRTYPE          192747
# LOCATION          191996
# SEVERITYCODE.1    194673
# SEVERITYDESC      194673
# COLLISIONTYPE     189769
# PERSONCOUNT       194673
# PEDCOUNT          194673
# PEDCYLCOUNT       194673
# VEHCOUNT          194673
# INCDATE           194673
# INCDTTM           194673
# JUNCTIONTYPE      188344
# INATTENTIONIND     29805
# UNDERINFL         189789
# WEATHER           189592
# ROADCOND          189661
# LIGHTCOND         189503
# PEDROWNOTGRNT       4667
# SPEEDING            9333
# SEGLANEKEY        194673
# CROSSWALKKEY      194673
# HITPARKEDCAR      194673
# dtype: int64

# %%
df.shape
# Out:
# (194673, 24)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 24)

# %%
# Out:
# OBJECTID           int64
# STATUS            object
# ADDRTYPE          object
# LOCATION          object
# SEVERITYCODE.1     int64
# SEVERITYDESC      object
# COLLISIONTYPE     object
# PERSONCOUNT        int64
# PEDCOUNT           int64
# PEDCYLCOUNT        int64
# VEHCOUNT           int64
# INCDATE           object
# INCDTTM           object
# JUNCTIONTYPE      object
# INATTENTIONIND    object
# UNDERINFL         object
# WEATHER           object
# ROADCOND          object
# LIGHTCOND         object
# PEDROWNOTGRNT     object
# SPEEDING          object
# SEGLANEKEY         int64
# CROSSWALKKEY       int64
# HITPARKEDCAR      object
# dtype: object
